# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sklearn

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le = LabelEncoder()

# %%
from sklearn.compose import ColumnTransformer

# %%
Data = pd.read_excel(r"C:\Users\HP\OneDrive\Documents\Capstone Project Files\Real_data.xlsx")

# %%
Data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Justin Watson   81    Male         B-            Asthma
# 1        Jennifer Wolf   30  Female        AB-            Cancer
# 2         Willie Huber   54    Male        AB-          Diabetes
# 3       Valerie Gentry   41  Female         O-           Obesity
# 4         Steven Smith   72  Female         A+         Arthritis
# ...                ...  ...     ...        ...               ...
# 14995   Maria Richards   76    Male         B-           Obesity
# 14996   Anthony Bailey   61    Male         A-          Diabetes
# 14997  Cynthia Bennett   29    Male        AB-          Diabetes
# 14998   Patrick Suarez   64  Female         A-            Cancer
# 14999    Tanya Bentley   56    Male         A-      Hypertension
#
#       Date of Admission           Doctor                      Hospital  \
# 0            2019-05-18    Melissa Allen        Williams Wilson, Brown
# 1            2022-09-21     Kelli Jordan        Lewis  Hartman French,
# 2            2020-11-07     Dylan Romero    Solis Armstrong, Garrison
# 3            2023-06-16  Timothy Compton       Gallegos,  Benson Sloan
# 4            2021-10-07       Eric Mccoy            Long White, Wells
# ...                 ...              ...                           ...
# 14995        2023-06-10      Yvonne Reed            Hayes Hurst, King
# 14996        2021-12-05  Kristin Lambert         Lyons, Johnson Fisher
# 14997        2023-08-16        Ethan May     Gutierrez Lopez Bennett,
# 14998        2021-10-09   Robert Fleming  Perez Zimmerman, Cunningham
# 14999        2023-10-11   Robyn Atkinson                   Inc Coleman
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0                  Aetna    10173.492460          349         Urgent
# 1                  Cigna    43302.169990          306      Emergency
# 2                  Aetna    38212.937280          420      Emergency
# 3               Medicare    24025.896650          460         Urgent
# 4             Blue Cross    10795.411650          182      Emergency
# ...                  ...             ...          ...            ...
# 14995   UnitedHealthcare    23176.473570          269       Elective
# 14996         Blue Cross     2468.808445          477         Urgent
# 14997           Medicare    19243.211950          472         Urgent
# 14998   UnitedHealthcare    35300.805620          401         Urgent
# 14999   UnitedHealthcare    24320.261740          282         Urgent
#
#       Discharge Date   Medication Test Results  Length_of_stay
# 0         2019-05-28      Lipitor     Abnormal              10
# 1         2022-10-12  Paracetamol     Abnormal              21
# 2         2020-12-03      Lipitor     Abnormal              26
# 3         2023-06-18    Ibuprofen     Abnormal               2
# 4         2021-10-12  Paracetamol     Abnormal               5
# ...              ...          ...          ...             ...
# 14995     2023-07-07   Penicillin     Abnormal              27
# 14996     2021-12-10  Paracetamol       Normal               5
# 14997     2023-08-17  Paracetamol     Abnormal               1
# 14998     2021-11-02   Penicillin     Abnormal              24
# 14999     2023-10-28    Ibuprofen       Normal              17
#
# [15000 rows x 16 columns]

# %%
Data.describe()
# Out:
#                 Age           Date of Admission  Billing Amount   Room Number  \
# count  15000.000000                       15000    15000.000000  15000.000000
# mean      51.531733  2021-11-02 09:39:21.600000    25607.766366    301.534333
# min       13.000000         2019-05-08 00:00:00       23.727930    101.000000
# 25%       35.000000         2020-08-03 00:00:00    13267.054552    200.000000
# 50%       52.000000         2021-11-02 00:00:00    25634.329540    303.000000
# 75%       69.000000         2023-01-29 00:00:00    37988.234440    403.000000
# max       89.000000         2024-05-07 00:00:00    52170.036850    500.000000
# std       19.633930                         NaN    14233.909973    116.266910
#
#                    Discharge Date  Length_of_stay
# count                       15000    15000.000000
# mean   2021-11-17 20:57:59.040000       15.471267
# min           2019-05-09 00:00:00        1.000000
# 25%           2020-08-17 00:00:00        8.000000
# 50%           2021-11-19 00:00:00       15.000000
# 75%           2023-02-13 00:00:00       23.000000
# max           2024-06-03 00:00:00       30.000000
# std                           NaN        8.695153

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                15000 non-null  object
#  1   Age                 15000 non-null  int64
#  2   Gender              15000 non-null  object
#  3   Blood Type          15000 non-null  object
#  4   Medical Condition   15000 non-null  object
#  5   Date of Admission   15000 non-null  datetime64[ns]
#  6   Doctor              15000 non-null  object
#  7   Hospital            15000 non-null  object
#  8   Insurance Provider  15000 non-null  object
#  9   Billing Amount      15000 non-null  float64
#  10  Room Number         15000 non-null  int64
#  11  Admission Type      15000 non-null  object
#  12  Discharge Date      15000 non-null  datetime64[ns]
#  13  Medication          15000 non-null  object
#  14  Test Results        15000 non-null  object
#  15  Length_of_stay      15000 non-null  int64
# dtypes: datetime64[ns](2), float64(1), int64(3), object(10)
# memory usage: 1.8+ MB

# %%
Data
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0        Justin Watson   81    Male         B-            Asthma
# 1        Jennifer Wolf   30  Female        AB-            Cancer
# 2         Willie Huber   54    Male        AB-          Diabetes
# 3       Valerie Gentry   41  Female         O-           Obesity
# 4         Steven Smith   72  Female         A+         Arthritis
# ...                ...  ...     ...        ...               ...
# 14995   Maria Richards   76    Male         B-           Obesity
# 14996   Anthony Bailey   61    Male         A-          Diabetes
# 14997  Cynthia Bennett   29    Male        AB-          Diabetes
# 14998   Patrick Suarez   64  Female         A-            Cancer
# 14999    Tanya Bentley   56    Male         A-      Hypertension
#
#       Date of Admission           Doctor                      Hospital  \
# 0            2019-05-18    Melissa Allen        Williams Wilson, Brown
# 1            2022-09-21     Kelli Jordan        Lewis  Hartman French,
# 2            2020-11-07     Dylan Romero    Solis Armstrong, Garrison
# 3            2023-06-16  Timothy Compton       Gallegos,  Benson Sloan
# 4            2021-10-07       Eric Mccoy            Long White, Wells
# ...                 ...              ...                           ...
# 14995        2023-06-10      Yvonne Reed            Hayes Hurst, King
# 14996        2021-12-05  Kristin Lambert         Lyons, Johnson Fisher
# 14997        2023-08-16        Ethan May     Gutierrez Lopez Bennett,
# 14998        2021-10-09   Robert Fleming  Perez Zimmerman, Cunningham
# 14999        2023-10-11   Robyn Atkinson                   Inc Coleman
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0                  Aetna    10173.492460          349         Urgent
# 1                  Cigna    43302.169990          306      Emergency
# 2                  Aetna    38212.937280          420      Emergency
# 3               Medicare    24025.896650          460         Urgent
# 4             Blue Cross    10795.411650          182      Emergency
# ...                  ...             ...          ...            ...
# 14995   UnitedHealthcare    23176.473570          269       Elective
# 14996         Blue Cross     2468.808445          477         Urgent
# 14997           Medicare    19243.211950          472         Urgent
# 14998   UnitedHealthcare    35300.805620          401         Urgent
# 14999   UnitedHealthcare    24320.261740          282         Urgent
#
#       Discharge Date   Medication Test Results  Length_of_stay
# 0         2019-05-28      Lipitor     Abnormal              10
# 1         2022-10-12  Paracetamol     Abnormal              21
# 2         2020-12-03      Lipitor     Abnormal              26
# 3         2023-06-18    Ibuprofen     Abnormal               2
# 4         2021-10-12  Paracetamol     Abnormal               5
# ...              ...          ...          ...             ...
# 14995     2023-07-07   Penicillin     Abnormal              27
# 14996     2021-12-10  Paracetamol       Normal               5
# 14997     2023-08-17  Paracetamol     Abnormal               1
# 14998     2021-11-02   Penicillin     Abnormal              24
# 14999     2023-10-28    Ibuprofen       Normal              17
#
# [15000 rows x 16 columns]

# %% [markdown]
# ***Data PreProcessing****
